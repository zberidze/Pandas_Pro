# %% [markdown]
# **Импорт всех необходимых библиотек**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option("display.max_rows", 20)
pd.set_option("display.max_columns", 20)
pd.set_option("display.precision", 4)
pd.set_option("plotting.backend", "matplotlib")

# %% [markdown]
# # 1. Исследовательский анализ данных (exploratory data analysis - EDA)

# %% [markdown]
# ## 1.1 Словесное описание признаков

# %% [markdown]
# <b><p>data.csv</p></b>
# <ul>
# <li>id: id транзакции </li>
# <li>timestamp: дата продажи (транзакции) </li>
# <li>full_sq: общая площадь  </li>
# <li>life_sq: жилая площадь  </li>
# <li>floor: этаж  </li>
# <li>max_floor: количество этажей в здании </li>
# <li>material: материал, из которого изговолены стены  </li>
# <li>build_year: год строительства </li>
# <li>num_room: количество жилых комнат </li>
# <li>kitch_sq: площадь кухни </li>
# <li>full_all: количество населения в регионе </li>
# <li> state: жилищные условия </li>
# <li>sub_area: название территории </li>
# <li>price_doc: цена квартиры (целевая переменная) </li>
# </ul>
#
# <b><p>macro.csv</p></b>
# <ul>
# <li>timestamp : дата, на которую актуальны макроэкономические показатели </li>
# <li>salary : средняя зарплата в регионе </li>
# <li>fixed_basket: стоимость потребительской корзины </li>
# <li>rent_price_3room_eco: стоимость аренды 3-х комнатного жилья эконом-класса </li>
# <li>rent_price_2room_eco: стоимость аренды 2-х комнатного жилья эконом-класса </li>
# <li>rent_price_1room_eco: стоимость аренды 1-но комнатного жилья эконом-класса </li>
# <li>average_life_exp: средняя продолжительность жизни в регионе </li>
# </ul>

# %% [markdown]
# |Признак|Наименование на русском|Комментарий|
# |--:|:--|:--|
# |`timestamp`|дата продажи (транзакции)| В среднем в день совершалось по 18 сделок, популярная дата продажи - 2014-12-16. В этот день было совершено - 133 сделки|
# |`full_sq`|общая площадь|В основном на продажу выставляются квартиры с небольшой площадью (от 38 кв.м до 63 кв.м.), однако наблюдаются и выбросы по min и max - 0 кв.м. и 5 326 кв.м.|
# |`life_sq`|жилая площадь| В среднем жилая площадь на 20 кв.м. меньше общей, показатели медианы  и средней (30 и 34 кв.м.) указывают на то, что в основном продаются 1-2-х комнатные квартиры. Имеются выбросы.|
# |`floor - max_floor`|этаж, максимальное количество этажей| Квартиры располагаются на этажах от 0 (ошибка в данных) до 77 |
# |`material`|материал, из которого изговолены стены| Больше всего квартир изготовленны из материала под номером 1. Всего видов материала  - 6|
# |`build_year`|год строительства| Больше всего квартир (919 квартир) построены в 2014 году . Всего количество разных лет в которые были построены квартиры -  120 |
# |`num_room`|количество жилых комнат| Есть комнаты с показателем 0 (возможно - аномалии), в среднем квартиры имеют по 2 комнаты, максимальное количество комнат - 19 |
# |`kitch_sq`|площадь кухни| Имеются квартиры с площадью кухни = 0 (возможно студии), в среднем площадь кухни равна 7 кв.м.|
# |`full_all`|количество населения в регионе| В датасесте наблюдается существенный разброс по колличеству населения от 2.5 тыс до 17 тыс. количество населения зависит от населения |
# |`sub_area`|название территории| Больше всего квартир продается в Nekrasovka (620 квартир). В целом продавались квартиры расположенные на 146 различных территориях|
# |`price_doc`|цена квартиры (целевая переменная)| |

# %% [markdown]
# ## 1.2 Загрузка данных общее описание набора данных

# %%
PATH_base = "https://raw.githubusercontent.com/aksenov7/Kaggle_competition_group/master/data.csv"
PATH_add = "https://raw.githubusercontent.com/aksenov7/Kaggle_competition_group/master/data_macro.csv"
df = pd.read_csv(PATH_base)
macro =  pd.read_csv(PATH_add)

# %% [markdown]
# ### 1.2.1 Базовый датасет

# %% [markdown]
# Вывести пример данных (первые строки и случайные строки)

# %%
df.sample(3)
# Out:
#           id   timestamp  full_sq  life_sq  floor  state  max_floor  material  \
# 9581   21279  2014-08-04       32     18.0    1.0    2.0        9.0       1.0
# 10827  22806  2014-09-23       89     89.0    5.0    1.0       17.0       1.0
# 14766  27787  2015-02-09       61     61.0    9.0    1.0        9.0       1.0
#
#       build_year  num_room  kitch_sq  full_all             sub_area  price_doc
# 9581      1971.0       1.0       6.0     64931  Vostochnoe Degunino    5200000
# 10827     2014.0       3.0      13.0     13890  Poselenie Sosenskoe    7170790
# 14766     2015.0       1.0       1.0    247469           Nekrasovka    6036800

# %% [markdown]
# Размер набора данных

# %%
df.shape
# Out:
# (18866, 14)

# %% [markdown]
# Описание типов данных по признакам

# %%
df.dtypes
# Out:
# id              int64
# timestamp      object
# full_sq         int64
# life_sq       float64
# floor         float64
# state         float64
# max_floor     float64
# material      float64
# build_year     object
# num_room      float64
# kitch_sq      float64
# full_all        int64
# sub_area       object
# price_doc       int64
# dtype: object

# %% [markdown]
# Базовые статистики по признакам

# %%
df.describe().transpose().style.background_gradient(cmap='Greens', axis=0)
# Out:
# <style type="text/css">
# #T_2c416_row0_col0, #T_2c416_row1_col0, #T_2c416_row9_col0, #T_2c416_row10_col0, #T_2c416_row10_col1, #T_2c416_row10_col2, #T_2c416_row10_col3, #T_2c416_row10_col4, #T_2c416_row10_col5, #T_2c416_row10_col6, #T_2c416_row10_col7 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_2c416_row0_col1, #T_2c416_row0_col2, #T_2c416_row0_col3, #T_2c416_row0_col4, #T_2c416_row0_col5, #T_2c416_row0_col6, #T_2c416_row0_col7, #T_2c416_row1_col1, #T_2c416_row1_col2, #T_2c416_row1_col3, #T_2c416_row1_col4, #T_2c416_row1_col5, #T_2c416_row1_col6, #T_2c416_row1_col7, #T_2c416_row2_col1, #T_2c416_row2_col2, #T_2c416_row2_col3, #T_2c416_row2_col4, #T_2c416_row2_col5, #T_2c416_row2_col6, #T_2c416_row2_col7, #T_2c416_row3_col1, #T_2c416_row3_col2, #T_2c416_row3_col3, #T_2c416_row3_col4, #T_2c416_row3_col5, #T_2c416_row3_col6, #T_2c416_row3_col7, #T_2c416_row4_col0, #T_2c416_row4_col1, #T_2c416_row4_col2, #T_2c416_row4_col3, #T_2c416_row4_col4, #T_2c416_row4_col5, #T_2c416_row4_col6, #T_2c416_row4_col7, #T_2c416_row5_col1, #T_2c416_row5_col2, #T_2c416_row5_col3, #T_2c416_row5_col4, #T_2c416_row5_col5, #T_2c416_row5_col6, #T_2c416_row5_col7, #T_2c416_row6_col1, #T_2c416_row6_col2, #T_2c416_row6_col3, #T_2c416_row6_col4, #T_2c416_row6_col5, #T_2c416_row6_col6, #T_2c416_row6_col7, #T_2c416_row7_col1, #T_2c416_row7_col2, #T_2c416_row7_col3, #T_2c416_row7_col4, #T_2c416_row7_col5, #T_2c416_row7_col6, #T_2c416_row7_col7, #T_2c416_row8_col1, #T_2c416_row8_col2, #T_2c416_row8_col3, #T_2c416_row8_col4, #T_2c416_row8_col5, #T_2c416_row8_col6, #T_2c416_row8_col7 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_2c416_row2_col0 {
#   background-color: #66bd6f;
#   color: #f1f1f1;
# }
# #T_2c416_row3_col0 {
#   background-color: #00471c;
#   color: #f1f1f1;
# }
# #T_2c416_row5_col0, #T_2c416_row6_col0, #T_2c416_row7_col0, #T_2c416_row8_col0 {
#   background-color: #55b567;
#   color: #f1f1f1;
# }
# #T_2c416_row9_col1 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_2c416_row9_col2 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_2c416_row9_col3 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_2c416_row9_col4 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_2c416_row9_col5, #T_2c416_row9_col6 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_2c416_row9_col7 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# </style>
# <table id="T_2c416_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#       <th class="col_heading level0 col3" >min</th>
#       <th class="col_heading level0 col4" >25%</th>
#       <th class="col_heading level0 col5" >50%</th>
#       <th class="col_heading level0 col6" >75%</th>
#       <th class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c416_level0_row0" class="row_heading level0 row0" >id</th>
#       <td id="T_2c416_row0_col0" class="data row0 col0" >18866.0000</td>
#       <td id="T_2c416_row0_col1" class="data row0 col1" >18799.7886</td>
#       <td id="T_2c416_row0_col2" class="data row0 col2" >7082.4287</td>
#       <td id="T_2c416_row0_col3" class="data row0 col3" >9.0000</td>
#       <td id="T_2c416_row0_col4" class="data row0 col4" >13513.2500</td>
#       <td id="T_2c416_row0_col5" class="data row0 col5" >19043.5000</td>
#       <td id="T_2c416_row0_col6" class="data row0 col6" >24748.7500</td>
#       <td id="T_2c416_row0_col7" class="data row0 col7" >30473.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2c416_level0_row1" class="row_heading level0 row1" >full_sq</th>
#       <td id="T_2c416_row1_col0" class="data row1 col0" >18866.0000</td>
#       <td id="T_2c416_row1_col1" class="data row1 col1" >53.9409</td>
#       <td id="T_2c416_row1_col2" class="data row1 col2" >44.1162</td>
#       <td id="T_2c416_row1_col3" class="data row1 col3" >0.0000</td>
#       <td id="T_2c416_row1_col4" class="data row1 col4" >38.0000</td>
#       <td id="T_2c416_row1_col5" class="data row1 col5" >49.0000</td>
#       <td id="T_2c416_row1_col6" class="data row1 col6" >63.0000</td>
#       <td id="T_2c416_row1_col7" class="data row1 col7" >5326.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2c416_level0_row2" class="row_heading level0 row2" >life_sq</th>
#       <td id="T_2c416_row2_col0" class="data row2 col0" >17291.0000</td>
#       <td id="T_2c416_row2_col1" class="data row2 col1" >34.2592</td>
#       <td id="T_2c416_row2_col2" class="data row2 col2" >59.9446</td>
#       <td id="T_2c416_row2_col3" class="data row2 col3" >0.0000</td>
#       <td id="T_2c416_row2_col4" class="data row2 col4" >20.0000</td>
#       <td id="T_2c416_row2_col5" class="data row2 col5" >30.0000</td>
#       <td id="T_2c416_row2_col6" class="data row2 col6" >43.0000</td>
#       <td id="T_2c416_row2_col7" class="data row2 col7" >7478.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2c416_level0_row3" class="row_heading level0 row3" >floor</th>
#       <td id="T_2c416_row3_col0" class="data row3 col0" >18838.0000</td>
#       <td id="T_2c416_row3_col1" class="data row3 col1" >7.2937</td>
#       <td id="T_2c416_row3_col2" class="data row3 col2" >5.1912</td>
#       <td id="T_2c416_row3_col3" class="data row3 col3" >0.0000</td>
#       <td id="T_2c416_row3_col4" class="data row3 col4" >3.0000</td>
#       <td id="T_2c416_row3_col5" class="data row3 col5" >6.0000</td>
#       <td id="T_2c416_row3_col6" class="data row3 col6" >10.0000</td>
#       <td id="T_2c416_row3_col7" class="data row3 col7" >77.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2c416_level0_row4" class="row_heading level0 row4" >state</th>
#       <td id="T_2c416_row4_col0" class="data row4 col0" >15505.0000</td>
#       <td id="T_2c416_row4_col1" class="data row4 col1" >2.2013</td>
#       <td id="T_2c416_row4_col2" class="data row4 col2" >0.8528</td>
#       <td id="T_2c416_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_2c416_row4_col4" class="data row4 col4" >2.0000</td>
#       <td id="T_2c416_row4_col5" class="data row4 col5" >2.0000</td>
#       <td id="T_2c416_row4_col6" class="data row4 col6" >3.0000</td>
#       <td id="T_2c416_row4_col7" class="data row4 col7" >33.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2c416_level0_row5" class="row_heading level0 row5" >max_floor</th>
#       <td id="T_2c416_row5_col0" class="data row5 col0" >17445.0000</td>
#       <td id="T_2c416_row5_col1" class="data row5 col1" >12.4233</td>
#       <td id="T_2c416_row5_col2" class="data row5 col2" >6.2798</td>
#       <td id="T_2c416_row5_col3" class="data row5 col3" >0.0000</td>
#       <td id="T_2c416_row5_col4" class="data row5 col4" >9.0000</td>
#       <td id="T_2c416_row5_col5" class="data row5 col5" >12.0000</td>
#       <td id="T_2c416_row5_col6" class="data row5 col6" >17.0000</td>
#       <td id="T_2c416_row5_col7" class="data row5 col7" >57.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2c416_level0_row6" class="row_heading level0 row6" >material</th>
#       <td id="T_2c416_row6_col0" class="data row6 col0" >17445.0000</td>
#       <td id="T_2c416_row6_col1" class="data row6 col1" >1.8901</td>
#       <td id="T_2c416_row6_col2" class="data row6 col2" >1.5061</td>
#       <td id="T_2c416_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_2c416_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_2c416_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_2c416_row6_col6" class="data row6 col6" >2.0000</td>
#       <td id="T_2c416_row6_col7" class="data row6 col7" >6.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2c416_level0_row7" class="row_heading level0 row7" >num_room</th>
#       <td id="T_2c416_row7_col0" class="data row7 col0" >17445.0000</td>
#       <td id="T_2c416_row7_col1" class="data row7 col1" >1.9348</td>
#       <td id="T_2c416_row7_col2" class="data row7 col2" >0.8642</td>
#       <td id="T_2c416_row7_col3" class="data row7 col3" >0.0000</td>
#       <td id="T_2c416_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_2c416_ro

# %%
df.describe(include=[object]).transpose()
# Out:
#             count unique         top freq
# timestamp   18866   1074  2014-12-16  133
# build_year  16866    120      2014.0  919
# sub_area    18866    146  Nekrasovka  620

# %% [markdown]
# Выводы текстом, что вы можете сказать по каждому признаку, на основе базовых статистик

# %% [markdown]
# Какие признаки вы считаете полезными для предсказания цены квартиры, а какие по вашему мнению можно убрать. Почему?

# %% [markdown]
# Есть ли пропуски в данных? В каких столбцах? Какой процент по каждому столбцу?

# %%
nan_df = df.isna().sum().to_frame().rename(columns={0:"count"})
nan_df['%'] = (df.isna().sum() / df.shape[0] * 100).round(2)
nan_df.sort_values("count", ascending=False).transpose().style.background_gradient(cmap='Reds', axis=1)
# Out:
# <style type="text/css">
# #T_73e5e_row0_col0, #T_73e5e_row1_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_73e5e_row0_col1, #T_73e5e_row1_col1 {
#   background-color: #f24633;
#   color: #f1f1f1;
# }
# #T_73e5e_row0_col2, #T_73e5e_row1_col2 {
#   background-color: #fb7555;
#   color: #f1f1f1;
# }
# #T_73e5e_row0_col3, #T_73e5e_row0_col4, #T_73e5e_row0_col5, #T_73e5e_row0_col6, #T_73e5e_row1_col3, #T_73e5e_row1_col4, #T_73e5e_row1_col5, #T_73e5e_row1_col6 {
#   background-color: #fc8262;
#   color: #f1f1f1;
# }
# #T_73e5e_row0_col7, #T_73e5e_row1_col7 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_73e5e_row0_col8, #T_73e5e_row0_col9, #T_73e5e_row0_col10, #T_73e5e_row0_col11, #T_73e5e_row0_col12, #T_73e5e_row0_col13, #T_73e5e_row1_col8, #T_73e5e_row1_col9, #T_73e5e_row1_col10, #T_73e5e_row1_col11, #T_73e5e_row1_col12, #T_73e5e_row1_col13 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_73e5e_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >state</th>
#       <th class="col_heading level0 col1" >build_year</th>
#       <th class="col_heading level0 col2" >life_sq</th>
#       <th class="col_heading level0 col3" >max_floor</th>
#       <th class="col_heading level0 col4" >material</th>
#       <th class="col_heading level0 col5" >num_room</th>
#       <th class="col_heading level0 col6" >kitch_sq</th>
#       <th class="col_heading level0 col7" >floor</th>
#       <th class="col_heading level0 col8" >id</th>
#       <th class="col_heading level0 col9" >timestamp</th>
#       <th class="col_heading level0 col10" >full_sq</th>
#       <th class="col_heading level0 col11" >full_all</th>
#       <th class="col_heading level0 col12" >sub_area</th>
#       <th class="col_heading level0 col13" >price_doc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73e5e_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_73e5e_row0_col0" class="data row0 col0" >3361.0000</td>
#       <td id="T_73e5e_row0_col1" class="data row0 col1" >2000.0000</td>
#       <td id="T_73e5e_row0_col2" class="data row0 col2" >1575.0000</td>
#       <td id="T_73e5e_row0_col3" class="data row0 col3" >1421.0000</td>
#       <td id="T_73e5e_row0_col4" class="data row0 col4" >1421.0000</td>
#       <td id="T_73e5e_row0_col5" class="data row0 col5" >1421.0000</td>
#       <td id="T_73e5e_row0_col6" class="data row0 col6" >1421.0000</td>
#       <td id="T_73e5e_row0_col7" class="data row0 col7" >28.0000</td>
#       <td id="T_73e5e_row0_col8" class="data row0 col8" >0.0000</td>
#       <td id="T_73e5e_row0_col9" class="data row0 col9" >0.0000</td>
#       <td id="T_73e5e_row0_col10" class="data row0 col10" >0.0000</td>
#       <td id="T_73e5e_row0_col11" class="data row0 col11" >0.0000</td>
#       <td id="T_73e5e_row0_col12" class="data row0 col12" >0.0000</td>
#       <td id="T_73e5e_row0_col13" class="data row0 col13" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_73e5e_level0_row1" class="row_heading level0 row1" >%</th>
#       <td id="T_73e5e_row1_col0" class="data row1 col0" >17.8200</td>
#       <td id="T_73e5e_row1_col1" class="data row1 col1" >10.6000</td>
#       <td id="T_73e5e_row1_col2" class="data row1 col2" >8.3500</td>
#       <td id="T_73e5e_row1_col3" class="data row1 col3" >7.5300</td>
#       <td id="T_73e5e_row1_col4" class="data row1 col4" >7.5300</td>
#       <td id="T_73e5e_row1_col5" class="data row1 col5" >7.5300</td>
#       <td id="T_73e5e_row1_col6" class="data row1 col6" >7.5300</td>
#       <td id="T_73e5e_row1_col7" class="data row1 col7" >0.1500</td>
#       <td id="T_73e5e_row1_col8" class="data row1 col8" >0.0000</td>
#       <td id="T_73e5e_row1_col9" class="data row1 col9" >0.0000</td>
#       <td id="T_73e5e_row1_col10" class="data row1 col10" >0.0000</td>
#       <td id="T_73e5e_row1_col11" class="data row1 col11" >0.0000</td>
#       <td id="T_73e5e_row1_col12" class="data row1 col12" >0.0000</td>
#       <td id="T_73e5e_row1_col13" class="data row1 col13" >0.0000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Есть ли аномальные данные в стллбцах? Если да, то укажите на них и объясните, почему считаете аномальными

# %%
df.columns
# Out:
# Index(['id', 'timestamp', 'full_sq', 'life_sq', 'floor', 'state', 'max_floor',
#        'material', 'build_year', 'num_room', 'kitch_sq', 'full_all',
#        'sub_area', 'price_doc'],
#       dtype='object')

# %% [markdown]
# ##### **1. timestamp**

# %%
df.timestamp = pd.to_datetime(df.timestamp)
df.timestamp.dt.year.sort_values().unique()
# Out:
# array([2011, 2012, 2013, 2014, 2015])

# %%
df.timestamp.describe(datetime_is_numeric=True).to_frame().transpose()
# Out:
#            count                          mean        min                 25%  \
# timestamp  18866 2014-05-14 05:19:03.008587008 2011-09-10 2013-12-27 06:00:00
#
#                  50%        75%        max
# timestamp 2014-05-28 2014-11-14 2015-06-30

# %%
df.timestamp.dt.year.value_counts().sort_index().to_frame().transpose().style.background_gradient(cmap='Greens', axis=1)
# Out:
# <style type="text/css">
# #T_d4dbf_row0_col0 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_d4dbf_row0_col1 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_d4dbf_row0_col2 {
#   background-color: #acdea6;
#   color: #000000;
# }
# #T_d4dbf_row0_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_d4dbf_row0_col4 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# </style>
# <table id="T_d4dbf_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >2011</th>
#       <th class="col_heading level0 col1" >2012</th>
#       <th class="col_heading level0 col2" >2013</th>
#       <th class="col_heading level0 col3" >2014</th>
#       <th class="col_heading level0 col4" >2015</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4dbf_level0_row0" class="row_heading level0 row0" >timestamp</th>
#       <td id="T_d4dbf_row0_col0" class="data row0 col0" >119</td>
#       <td id="T_d4dbf_row0_col1" class="data row0 col1" >702</td>
#       <td id="T_d4dbf_row0_col2" class="data row0 col2" >3948</td>
#       <td id="T_d4dbf_row0_col3" class="data row0 col3" >11450</td>
#       <td id="T_d4dbf_row0_col4" class="data row0 col4" >2647</td>
#     </tr>
#   </tbody>
# </table>

# %%
sale_months = df.timestamp.dt.month
print(all(sale_months.isin(range(13))), sale_months.nunique())
sale_months.value_counts().sort_index().to_frame().transpose().style.background_gradient(cmap='Greens', axis=1)
# Out:
# True 12
# <style type="text/css">
# #T_9601e_row0_col0 {
#   background-color: #def2d9;
#   color: #000000;
# }
# #T_9601e_row0_col1 {
#   background-color: #95d391;
#   color: #000000;
# }
# #T_9601e_row0_col2 {
#   background-color: #62bb6d;
#   color: #f1f1f1;
# }
# #T_9601e_row0_col3 {
#   background-color: #319a50;
#   color: #f1f1f1;
# }
# #T_9601e_row0_col4 {
#   background-color: #91d28e;
#   color: #000000;
# }
# #T_9601e_row0_col5 {
#   background-color: #83cb82;
#   color: #000000;
# }
# #T_9601e_row0_col6 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_9601e_row0_col7 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_9601e_row0_col8 {
#   background-color: #94d390;
#   color: #000000;
# }
# #T_9601e_row0_col9 {
#   background-color: #48ae60;
#   color: #f1f1f1;
# }
# #T_9601e_row0_col10 {
#   background-color: #2d954d;
#   color: #f1f1f1;
# }
# #T_9601e_row0_col11 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9601e_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >1</th>
#       <th class="col_heading level0 col1" >2</th>
#       <th class="col_heading level0 col2" >3</th>
#       <th class="col_heading level0 col3" >4</th>
#       <th class="col_heading level0 col4" >5</th>
#       <th class="col_heading level0 col5" >6</th>
#       <th class="col_heading level0 col6" >7</th>
#       <th class="col_heading level0 col7" >8</th>
#       <th class="col_heading level0 col8" >9</th>
#       <th class="col_heading level0 col9" >10</th>
#       <th class="col_heading level0 col10" >11</th>
#       <th class="col_heading level0 col11" >12</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9601e_level0_row0" class="row_heading level0 row0" >timestamp</th>
#       <td id="T_9601e_row0_col0" class="data row0 col0" >1164</td>
#       <td id="T_9601e_row0_col1" class="data row0 col1" >1504</td>
#       <td id="T_9601e_row0_col2" class="data row0 col2" >1686</td>
#       <td id="T_9601e_row0_col3" class="data row0 col3" >1877</td>
#       <td id="T_9601e_row0_col4" class="data row0 col4" >1516</td>
#       <td id="T_9601e_row0_col5" class="data row0 col5" >1570</td>
#       <td id="T_9601e_row0_col6" class="data row0 col6" >957</td>
#       <td id="T_9601e_row0_col7" class="data row0 col7" >1123</td>
#       <td id="T_9601e_row0_col8" class="data row0 col8" >1506</td>
#       <td id="T_9601e_row0_col9" class="data row0 col9" >1767</td>
#       <td id="T_9601e_row0_col10" class="data row0 col10" >1903</td>
#       <td id="T_9601e_row0_col11" class="data row0 col11" >2293</td>
#     </tr>
#   </tbody>
# </table>

# %%
sale_days = df.timestamp.dt.day
print(all(sale_days.isin(range(32))), sale_days.nunique())
sale_days.value_counts().sort_index().to_frame().transpose().style.background_gradient(cmap='Greens', axis=1)
# Out:
# True 31
# <style type="text/css">
# #T_a00a0_row0_col0 {
#   background-color: #afdfa8;
#   color: #000000;
# }
# #T_a00a0_row0_col1 {
#   background-color: #9ed798;
#   color: #000000;
# }
# #T_a00a0_row0_col2 {
#   background-color: #75c477;
#   color: #000000;
# }
# #T_a00a0_row0_col3 {
#   background-color: #4db163;
#   color: #f1f1f1;
# }
# #T_a00a0_row0_col4 {
#   background-color: #50b264;
#   color: #f1f1f1;
# }
# #T_a00a0_row0_col5 {
#   background-color: #62bb6d;
#   color: #f1f1f1;
# }
# #T_a00a0_row0_col6 {
#   background-color: #8dd08a;
#   color: #000000;
# }
# #T_a00a0_row0_col7 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# #T_a00a0_row0_col8 {
#   background-color: #5eb96b;
#   color: #f1f1f1;
# }
# #T_a00a0_row0_col9 {
#   background-color: #3ea75a;
#   color: #f1f1f1;
# }
# #T_a00a0_row0_col10 {
#   background-color: #268e47;
#   color: #f1f1f1;
# }
# #T_a00a0_row0_col11 {
#   background-color: #5bb86a;
#   color: #f1f1f1;
# }
# #T_a00a0_row0_col12 {
#   background-color: #72c375;
#   color: #000000;
# }
# #T_a00a0_row0_col13 {
#   background-color: #52b365;
#   color: #f1f1f1;
# }
# #T_a00a0_row0_col14 {
#   background-color: #4aaf61;
#   color: #f1f1f1;
# }
# #T_a00a0_row0_col15 {
#   background-color: #097532;
#   color: #f1f1f1;
# }
# #T_a00a0_row0_col16 {
#   background-color: #1d8640;
#   color: #f1f1f1;
# }
# #T_a00a0_row0_col17 {
#   background-color: #006027;
#   color: #f1f1f1;
# }
# #T_a00a0_row0_col18 {
#   background-color: #067230;
#   color: #f1f1f1;
# }
# #T_a00a0_row0_col19, #T_a00a0_row0_col29 {
#   background-color: #006428;
#   color: #f1f1f1;
# }
# #T_a00a0_row0_col20 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_a00a0_row0_col21 {
#   background-color: #58b668;
#   color: #f1f1f1;
# }
# #T_a00a0_row0_col22 {
#   background-color: #42ab5d;
#   color: #f1f1f1;
# }
# #T_a00a0_row0_col23 {
#   background-color: #03702e;
#   color: #f1f1f1;
# }
# #T_a00a0_row0_col24 {
#   background-color: #006b2b;
#   color: #f1f1f1;
# }
# #T_a00a0_row0_col25 {
#   background-color: #005120;
#   color: #f1f1f1;
# }
# #T_a00a0_row0_col26 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_a00a0_row0_col27 {
#   background-color: #208843;
#   color: #f1f1f1;
# }
# #T_a00a0_row0_col28 {
#   background-color: #45ad5f;
#   color: #f1f1f1;
# }
# #T_a00a0_row0_col30 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_a00a0_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >1</th>
#       <th class="col_heading level0 col1" >2</th>
#       <th class="col_heading level0 col2" >3</th>
#       <th class="col_heading level0 col3" >4</th>
#       <th class="col_heading level0 col4" >5</th>
#       <th class="col_heading level0 col5" >6</th>
#       <th class="col_heading level0 col6" >7</th>
#       <th class="col_heading level0 col7" >8</th>
#       <th class="col_heading level0 col8" >9</th>
#       <th class="col_heading level0 col9" >10</th>
#       <th class="col_heading level0 col10" >11</th>
#       <th class="col_heading level0 col11" >12</th>
#       <th class="col_heading level0 col12" >13</th>
#       <th class="col_heading level0 col13" >14</th>
#       <th class="col_heading level0 col14" >15</th>
#       <th class="col_heading level0 col15" >16</th>
#       <th class="col_heading level0 col16" >17</th>
#       <th class="col_heading level0 col17" >18</th>
#       <th class="col_heading level0 col18" >19</th>
#       <th class="col_heading level0 col19" >20</th>
#       <th class="col_heading level0 col20" >21</th>
#       <th class="col_heading level0 col21" >22</th>
#       <th class="col_heading level0 col22" >23</th>
#       <th class="col_heading level0 col23" >24</th>
#       <th class="col_heading level0 col24" >25</th>
#       <th class="col_heading level0 col25" >26</th>
#       <th class="col_heading level0 col26" >27</th>
#       <th class="col_heading level0 col27" >28</th>
#       <th class="col_heading level0 col28" >29</th>
#       <th class="col_heading level0 col29" >30</th>
#       <th class="col_heading level0 col30" >31</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a00a0_level0_row0" class="row_heading level0 row0" >timestamp</th>
#       <td id="T_a00a0_row0_col0" class="data row0 col0" >478</td>
#       <td id="T_a00a0_row0_col1" class="data row0 col1" >499</td>
#       <td id="T_a00a0_row0_col2" class="data row0 col2" >546</td>
#       <td id="T_a00a0_row0_col3" class="data row0 col3" >585</td>
#       <td id="T_a00a0_row0_col4" class="data row0 col4" >582</td>
#       <td id="T_a00a0_row0_col5" class="data row0 col5" >565</td>
#       <td id="T_a00a0_row0_col6" class="data row0 col6" >519</td>
#       <td id="T_a00a0_row0_col7" class="data row0 col7" >535</td>
#       <td id="T_a00a0_row0_col8" class="data row0 col8" >568</td>
#       <td id="T_a00a0_row0_col9" class="data row0 col9" >603</td>
#       <td id="T_a00a0_row0_col10" class="data row0 col10" >643</td>
#       <td id="T_a00a0_row0_col11" class="data row0 col11" >571</td>
#       <td id="T_a00a0_row0_col12" class="data row0 col12" >549</td>
#       <td id="T_a00a0_row0_col13" class="data row0 col13" >581</td>
#       <td id="T_a00a0_row0_col14" class="data row0 col14" >588</td>
#       <td id="T_a00a0_row0_col15" class="data row0 col15" >685</td>
#       <td id="T_a00a0_row0_col16" class="data row0 col16" >657</td>
#       <td id="T_a00a0_row0_col17" class="data row0 col17" >714</td>
#       <td id="T_a00a0_row0_col18" class="data row0 col18" >690</td>
#       <td id="T_a00a0_row0_col19" class="data row0 col19" >710</td>
#       <td id="T_a00a0_row0_col20" class="data row0 col20" >649</td>
#       <td id="T_a00a0_row0_col21" class="data row0 col21" >575</td>
#       <td id="T_a00a0_row0_col22" class="data row0 col22" >597</td>
#       <td id="T_a00a0_row0_col23" class="data row0 col23" >693</td>
#       <td id="T_a00a0_row0_col24" class="data row0 col24" >702</td>
#       <td id="T_a00a0_row0_col25" class="data row0 col25" >734</td>
#       <td id="T_a00a0_row0_col26" class="data row0 col26" >750</td>
#       <td id="T_a00a0_row0_col27" class="data row0 col27" >653</td>
#       <td id="T_a00a0_row0_col28" class="data row0 col28" >593</td>
#       <td id="T_a00a0_row0_col29" class="data row0 col29" >709</td>
#       <td id="T_a00a0_row0_col30" class="data row0 col30" >343</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### **2. full_sq**

# %%
df.full_sq.describe()
# Out:
# count    18866.0000
# mean        53.9409
# std         44.1162
# min          0.0000
# 25%         38.0000
# 50%         49.0000
# 75%         63.0000
# max       5326.0000
# Name: full_sq, dtype: float64

# %% [markdown]
# ##### **3. life_sq**

# %%
# d = df.copy()
# print(d.isna().sum().to_frame().transpose())
columns = ['num_room', 'max_floor', 'floor', 'kitch_sq', 'life_sq']
d.material = d.material.fillna(d.material.mode()[0])
gr_obj = d.groupby(['sub_area','material'], as_index=False)[columns].transform("mean")
for column in columns:
    d.loc[d[column].isna(), column] = gr_obj.loc[d[column].isna(), column]
print(d.isna().sum().to_frame().transpose())
d.head()
# Out:
#    id  timestamp  full_sq  life_sq  floor  state  max_floor  material  \
# 0   0          0        0     1575     28   3361       1421      1421
#
#    build_year  num_room  kitch_sq  full_all  sub_area  price_doc
# 0        2000      1421      1421         0         0          0
#    id  timestamp  full_sq  life_sq  floor  state  max_floor  material  \
# 0   0          0        0        7      0   3361          1         0
#
#    build_year  num_room  kitch_sq  full_all  sub_area  price_doc
# 0        2000         1         1         0         0          0
#      id  timestamp  full_sq  life_sq  floor  state  max_floor  material  \
# 0  8059 2013-05-21       11     11.0    2.0    3.0        5.0       2.0
# 1  8138 2013-05-25       53     30.0   10.0    3.0       16.0       1.0
# 2  8156 2013-05-27       77     41.0    2.0    1.0       17.0       6.0
# 3  8157 2013-05-27       45     27.0    6.0    3.0        9.0       1.0
# 4  8178 2013-05-28       38     20.0   15.0    NaN       16.0       1.0
#
#   build_year  num_room  kitch_sq  full_all                 sub_area  price_doc
# 0     1907.0       1.0      12.0     75377                Hamovniki    2750000
# 1     1980.0       2.0       8.0     68630                Lianozovo    9000000
# 2     2014.0       3.0      12.0      9553  Poselenie Voskresenskoe    7011550
# 3     1970.0       2.0       6.0     78616          Severnoe Butovo    7100000
# 4     1982.0       1.0       8.0    112804           Filevskij Park    6450000

# %%
d
# Out:
#           id  timestamp  full_sq  life_sq  floor  state  max_floor  material  \
# 0       8059 2013-05-21       11     11.0    2.0    3.0        5.0       2.0
# 1       8138 2013-05-25       53     30.0   10.0    3.0       16.0       1.0
# 2       8156 2013-05-27       77     41.0    2.0    1.0       17.0       6.0
# 3       8157 2013-05-27       45     27.0    6.0    3.0        9.0       1.0
# 4       8178 2013-05-28       38     20.0   15.0    NaN       16.0       1.0
# ...      ...        ...      ...      ...    ...    ...        ...       ...
# 18861  21562 2014-08-15       78      NaN   14.0    NaN        0.0       6.0
# 18862   4796 2012-11-19       99     91.0   20.0    NaN        NaN       NaN
# 18863    466 2011-11-25       38     24.0    1.0    NaN        NaN       NaN
# 18864  27416 2015-01-21       77      NaN   11.0    NaN        0.0       1.0
# 18865   1723 2012-03-29       35     17.0    1.0    NaN        NaN       NaN
#
#       build_year  num_room  kitch_sq  full_all                 sub_area  \
# 0         1907.0       1.0      12.0     75377                Hamovniki
# 1         1980.0       2.0       8.0     68630                Lianozovo
# 2         2014.0       3.0      12.0      9553  Poselenie Voskresenskoe
# 3         1970.0       2.0       6.0     78616          Severnoe Butovo
# 4         1982.0       1.0       8.0    112804           Filevskij Park
# ...          ...       ...       ...       ...                      ...
# 18861        NaN       2.0       0.0      7341     Poselenie Moskovskij
# 18862        NaN       NaN       NaN     28179                Basmannoe
# 18863        NaN       NaN       NaN    142462               Mozhajskoe
# 18864        NaN       3.0       0.0     39873     Poselenie Shherbinka
# 18865        NaN       NaN       NaN    125354      Chertanovo Severnoe
#
#        price_doc
# 0        2750000
# 1        9000000
# 2        7011550
# 3        7100000
# 4        6450000
# ...          ...
# 18861    7722029
# 18862   14800000
# 18863    6300000
# 18864    5966828
# 18865    5250000
#
# [18866 rows x 14 columns]

# %%
gr_obj
# Out:
#        num_room  max_floor    floor
# 0        2.5000     7.0500   4.2500
# 1        1.7647    14.2353   8.7059
# 2        2.1429     9.2857   7.6429
# 3        2.0133    15.4800   9.0133
# 5        1.7586    18.0690  11.2069
# ...         ...        ...      ...
# 18796    1.7872    16.2766   9.5775
# 18797    1.5200     8.4800   5.4800
# 18833    2.0435    11.9565   7.7391
# 18851    1.8305    13.1525   7.4915
# 18860    2.3333     5.7576   7.3030
#
# [15505 rows x 3 columns]

# %% [markdown]
# ##### **4. floor**

# %% [markdown]
# ##### **5. state**

# %% [markdown]
# ##### **6. state**

# %% [markdown]
# ##### **7. max_floor**

# %% [markdown]
# ##### **8. material**

# %% [markdown]
# ##### **9. build_year**

# %% [markdown]
# ##### **10. num_room**

# %% [markdown]
# ##### **11. kitch_sq**

# %% [markdown]
# ##### **12. full_all**

# %% [markdown]
# ##### **13. sub_area**

# %% [markdown]
# ##### **14. price_doc**

# %% [markdown]
# ### 1.2.2 Макро показатели

# %% [markdown]
# Вывести пример данных (первые строки и случайные строки)

# %%
macro.sample(3)
# Out:
#        timestamp   salary  fixed_basket  rent_price_3room_eco  \
# 493   2011-05-09  44898.7      13068.42                 43.71
# 193   2010-07-13  38410.5      11708.46                   NaN
# 2335  2016-05-24      NaN      20031.98                 47.57
#
#       rent_price_2room_eco  rent_price_1room_eco  average_life_exp
# 493                  35.89                 27.94             75.79
# 193                    NaN                   NaN             74.20
# 2335                 36.96                 29.16               NaN

# %% [markdown]
# Размер набора данных

# %%
macro.shape
# Out:
# (2484, 7)

# %% [markdown]
# Описание типов данных по признакам

# %%
macro.dtypes
# Out:
# timestamp                object
# salary                  float64
# fixed_basket            float64
# rent_price_3room_eco    float64
# rent_price_2room_eco    float64
# rent_price_1room_eco    float64
# average_life_exp        float64
# dtype: object

# %% [markdown]
# Базовые статистики по признакам

# %%
macro.describe().transpose().style.background_gradient(cmap='Greens', axis=1)
# Out:
# <style type="text/css">
# #T_0e45e_row0_col0, #T_0e45e_row1_col0, #T_0e45e_row2_col2, #T_0e45e_row3_col2, #T_0e45e_row3_col3, #T_0e45e_row4_col2, #T_0e45e_row4_col3, #T_0e45e_row5_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_0e45e_row0_col1 {
#   background-color: #137d39;
#   color: #f1f1f1;
# }
# #T_0e45e_row0_col2 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_0e45e_row0_col3, #T_0e45e_row1_col4 {
#   background-color: #52b365;
#   color: #f1f1f1;
# }
# #T_0e45e_row0_col4 {
#   background-color: #319a50;
#   color: #f1f1f1;
# }
# #T_0e45e_row0_col5 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_0e45e_row0_col6 {
#   background-color: #005321;
#   color: #f1f1f1;
# }
# #T_0e45e_row0_col7, #T_0e45e_row1_col7, #T_0e45e_row2_col0, #T_0e45e_row3_col0, #T_0e45e_row4_col0, #T_0e45e_row5_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_0e45e_row1_col1 {
#   background-color: #2b934b;
#   color: #f1f1f1;
# }
# #T_0e45e_row1_col2, #T_0e45e_row2_col4, #T_0e45e_row3_col1, #T_0e45e_row3_col4, #T_0e45e_row3_col5, #T_0e45e_row3_col6 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_0e45e_row1_col3 {
#   background-color: #75c477;
#   color: #000000;
# }
# #T_0e45e_row1_col5 {
#   background-color: #2f984f;
#   color: #f1f1f1;
# }
# #T_0e45e_row1_col6 {
#   background-color: #006b2b;
#   color: #f1f1f1;
# }
# #T_0e45e_row2_col1, #T_0e45e_row2_col5, #T_0e45e_row2_col6, #T_0e45e_row2_col7, #T_0e45e_row3_col7 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_0e45e_row2_col3, #T_0e45e_row4_col1, #T_0e45e_row4_col4, #T_0e45e_row4_col5, #T_0e45e_row4_col6, #T_0e45e_row4_col7 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_0e45e_row5_col1, #T_0e45e_row5_col3, #T_0e45e_row5_col4, #T_0e45e_row5_col5, #T_0e45e_row5_col6, #T_0e45e_row5_col7 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# </style>
# <table id="T_0e45e_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#       <th class="col_heading level0 col3" >min</th>
#       <th class="col_heading level0 col4" >25%</th>
#       <th class="col_heading level0 col5" >50%</th>
#       <th class="col_heading level0 col6" >75%</th>
#       <th class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e45e_level0_row0" class="row_heading level0 row0" >salary</th>
#       <td id="T_0e45e_row0_col0" class="data row0 col0" >2191.0000</td>
#       <td id="T_0e45e_row0_col1" class="data row0 col1" >52188.9331</td>
#       <td id="T_0e45e_row0_col2" class="data row0 col2" >9068.5590</td>
#       <td id="T_0e45e_row0_col3" class="data row0 col3" >38410.5000</td>
#       <td id="T_0e45e_row0_col4" class="data row0 col4" >44898.7000</td>
#       <td id="T_0e45e_row0_col5" class="data row0 col5" >48830.4000</td>
#       <td id="T_0e45e_row0_col6" class="data row0 col6" >61208.0000</td>
#       <td id="T_0e45e_row0_col7" class="data row0 col7" >64310.0000</td>
#     </tr>
#     <tr>
#       <th id="T_0e45e_level0_row1" class="row_heading level0 row1" >fixed_basket</th>
#       <td id="T_0e45e_row1_col0" class="data row1 col0" >2484.0000</td>
#       <td id="T_0e45e_row1_col1" class="data row1 col1" >15331.4980</td>
#       <td id="T_0e45e_row1_col2" class="data row1 col2" >2789.1363</td>
#       <td id="T_0e45e_row1_col3" class="data row1 col3" >11443.6300</td>
#       <td id="T_0e45e_row1_col4" class="data row1 col4" >12992.4400</td>
#       <td id="T_0e45e_row1_col5" class="data row1 col5" >14983.9200</td>
#       <td id="T_0e45e_row1_col6" class="data row1 col6" >18295.0700</td>
#       <td id="T_0e45e_row1_col7" class="data row1 col7" >20422.5000</td>
#     </tr>
#     <tr>
#       <th id="T_0e45e_level0_row2" class="row_heading level0 row2" >rent_price_3room_eco</th>
#       <td id="T_0e45e_row2_col0" class="data row2 col0" >2211.0000</td>
#       <td id="T_0e45e_row2_col1" class="data row2 col1" >47.2997</td>
#       <td id="T_0e45e_row2_col2" class="data row2 col2" >3.0702</td>
#       <td id="T_0e45e_row2_col3" class="data row2 col3" >37.5400</td>
#       <td id="T_0e45e_row2_col4" class="data row2 col4" >45.5300</td>
#       <td id="T_0e45e_row2_col5" class="data row2 col5" >47.3500</td>
#       <td id="T_0e45e_row2_col6" class="data row2 col6" >49.3500</td>
#       <td id="T_0e45e_row2_col7" class="data row2 col7" >53.2100</td>
#     </tr>
#     <tr>
#       <th id="T_0e45e_level0_row3" class="row_heading level0 row3" >rent_price_2room_eco</th>
#       <td id="T_0e45e_row3_col0" class="data row3 col0" >2211.0000</td>
#       <td id="T_0e45e_row3_col1" class="data row3 col1" >38.8954</td>
#       <td id="T_0e45e_row3_col2" class="data row3 col2" >5.0352</td>
#       <td id="T_0e45e_row3_col3" class="data row3 col3" >0.1000</td>
#       <td id="T_0e45e_row3_col4" class="data row3 col4" >37.9300</td>
#       <td id="T_0e45e_row3_col5" class="data row3 col5" >39.4700</td>
#       <td id="T_0e45e_row3_col6" class="data row3 col6" >41.3000</td>
#       <td id="T_0e45e_row3_col7" class="data row3 col7" >43.8500</td>
#     </tr>
#     <tr>
#       <th id="T_0e45e_level0_row4" class="row_heading level0 row4" >rent_price_1room_eco</th>
#       <td id="T_0e45e_row4_col0" class="data row4 col0" >2211.0000</td>
#       <td id="T_0e45e_row4_col1" class="data row4 col1" >31.0024</td>
#       <td id="T_0e45e_row4_col2" class="data row4 col2" >3.9841</td>
#       <td id="T_0e45e_row4_col3" class="data row4 col3" >2.3100</td>
#       <td id="T_0e45e_row4_col4" class="data row4 col4" >29.7800</td>
#       <td id="T_0e45e_row4_col5" class="data row4 col5" >31.1100</td>
#       <td id="T_0e45e_row4_col6" class="data row4 col6" >33.0600</td>
#       <td id="T_0e45e_row4_col7" class="data row4 col7" >35.3700</td>
#     </tr>
#     <tr>
#       <th id="T_0e45e_level0_row5" class="row_heading level0 row5" >average_life_exp</th>
#       <td id="T_0e45e_row5_col0" class="data row5 col0" >2191.0000</td>
#       <td id="T_0e45e_row5_col1" class="data row5 col1" >75.9282</td>
#       <td id="T_0e45e_row5_col2" class="data row5 col2" >0.8699</td>
#       <td id="T_0e45e_row5_col3" class="data row5 col3" >74.2000</td>
#       <td id="T_0e45e_row5_col4" class="data row5 col4" >75.7400</td>
#       <td id="T_0e45e_row5_col5" class="data row5 col5" >75.7900</td>
#       <td id="T_0e45e_row5_col6" class="data row5 col6" >76.7000</td>
#       <td id="T_0e45e_row5_col7" class="data row5 col7" >76.7700</td>
#     </tr>
#   </tbody>
# </table>

# %%
macro.describe(include=[object]).transpose()
# Out:
#           count unique         top freq
# timestamp  2484   2484  2010-01-01    1

# %% [markdown]
# Выводы текстом, что вы можете сказать по каждому признаку, на основе базовых статистик

# %% [markdown]
# Какие признаки вы считаете полезными для предсказания цены квартиры, а какие по вашему мнению можно убрать. Почему?

# %% [markdown]
# Есть ли пропуски в данных? В каких столбцах? Какой процент по каждому столбцу?

# %%
macro_nan_df = macro.isna().sum().to_frame().rename(columns={0:"count"})
macro_nan_df['%'] = (macro.isna().sum() / macro.shape[0] * 100).round(2)
macro_nan_df.sort_values("count", ascending=False).transpose().style.background_gradient(cmap='Reds', axis=1)
# Out:
# <style type="text/css">
# #T_6d004_row0_col0, #T_6d004_row0_col1, #T_6d004_row1_col0, #T_6d004_row1_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_6d004_row0_col2, #T_6d004_row0_col3, #T_6d004_row0_col4, #T_6d004_row1_col2, #T_6d004_row1_col3, #T_6d004_row1_col4 {
#   background-color: #880811;
#   color: #f1f1f1;
# }
# #T_6d004_row0_col5, #T_6d004_row0_col6, #T_6d004_row1_col5, #T_6d004_row1_col6 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_6d004_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >salary</th>
#       <th class="col_heading level0 col1" >average_life_exp</th>
#       <th class="col_heading level0 col2" >rent_price_3room_eco</th>
#       <th class="col_heading level0 col3" >rent_price_2room_eco</th>
#       <th class="col_heading level0 col4" >rent_price_1room_eco</th>
#       <th class="col_heading level0 col5" >timestamp</th>
#       <th class="col_heading level0 col6" >fixed_basket</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d004_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_6d004_row0_col0" class="data row0 col0" >293.0000</td>
#       <td id="T_6d004_row0_col1" class="data row0 col1" >293.0000</td>
#       <td id="T_6d004_row0_col2" class="data row0 col2" >273.0000</td>
#       <td id="T_6d004_row0_col3" class="data row0 col3" >273.0000</td>
#       <td id="T_6d004_row0_col4" class="data row0 col4" >273.0000</td>
#       <td id="T_6d004_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_6d004_row0_col6" class="data row0 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_6d004_level0_row1" class="row_heading level0 row1" >%</th>
#       <td id="T_6d004_row1_col0" class="data row1 col0" >11.8000</td>
#       <td id="T_6d004_row1_col1" class="data row1 col1" >11.8000</td>
#       <td id="T_6d004_row1_col2" class="data row1 col2" >10.9900</td>
#       <td id="T_6d004_row1_col3" class="data row1 col3" >10.9900</td>
#       <td id="T_6d004_row1_col4" class="data row1 col4" >10.9900</td>
#       <td id="T_6d004_row1_col5" class="data row1 col5" >0.0000</td>
#       <td id="T_6d004_row1_col6" class="data row1 col6" >0.0000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Есть ли аномальные данные в стллбцах? Если да, то укажите на них и объясните, почему считаете аномальными

# %% [markdown]
# ## 1.3 Замените все ранее найденные ошибочные данные на None. Заполните все пропуски в данных: которые были и которые появились. Используйте как стратегии изученные на занятии, так и логику, которая вытекает из самих данных

# %% [markdown]
# ### 1.3.1 Главный набор данных

# %% [markdown]
# ### 1.3.2 Набор с макропоказателями

# %% [markdown]
# ## 1.4 Обогатите основной набор данных данными из макропоказателей и поместите в переменную `df_full`

# %% [markdown]
# ## 1.5 Проверьте данные на наличие выбросов. По каждому столбцу. Напишите своё мнение: нужно ли в каждой из ситуаций обрабатывать выбросы, или можно оставить. Если нужно обработать, то примените один из изученных подходов, либо предложите свой

# %% [markdown]
# ### 1.5.1 Главный набор данных

# %% [markdown]
# ### 1.5.2 Набор с макропоказателями

# %% [markdown]
# ## 1.6 Создайте не менее 5 новых признаков на основе существующих данных. Опишите текстом обоснование создания каждой. Признаки должны привносить некую новую информацию для понимания цены квартиры

# %% [markdown]
# ## 1.7 Провести визуальный анализ всех признаков
#
# Ко всем графикам писать выводы текстом. Что вы видите, почему построили именно такую диаграмму

# %% [markdown]
# ### 1.7.1 Анализ признаков по отдельности (где нужно делать группировки, преобразования категориальных типов данных к числовым, смотреть в разрезе других категориальных признаков)

# %% [markdown]
# ### 1.7.2 Анализ совместного влияния признаков и их влияния на целевой признак
